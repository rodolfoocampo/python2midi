# %%
import mido
from mido import MidiFile
import time
import requests
import json
import pandas as pd
import numpy as np
import time
import random

# %% [markdown]
# ### Set up of midi and Python and sending a note
#
# As per this blog post, setting up a Python-Midi port connection is extremely simple on a Mac. Just follow these steps:
#
# https://natespilman.com/blog/2020-03-23-generating-midi-music-stream-with-python/
#
# We have created a port called 'python' using the IAC Driver. The IAC Driver let's you route MIDI messages between applications. Hence, Inter Application Communication.
#
# Having done that, we can use mido to send messages to the 'IAC Driver port'

# %%
msg = mido.Message('note_on', note=72, velocity=64, time=5000)
outport = mido.open_output('IAC Driver python')
outport.send(msg)

# %% [markdown]
# # Notes on MIDI messages
#
# A MIDI message is made up of an eight-bit status byte which is generally followed by one or two data bytes. There are a number of different types of MIDI messages. At the highest level, MIDI messages are classified as being either Channel Messages or System Messages. Channel messages are those which apply to a specific Channel, and the Channel number is included in the status byte for these messages. System messages are not Channel specific, and no Channel number is indicated in their status bytes.
#
# Channel Messages may be further classified as being either Channel Voice Messages, or Mode Messages. Channel Voice Messages carry musical performance data, and these messages comprise most of the traffic in a typical MIDI data stream. Channel Mode messages affect the way a receiving instrument will respond to the Channel Voice messages.

# %% [markdown]
# We can just create a two note interval and send them as messages with a velocity of 64.

# %%
notes = []
for i in range(60,65,4):
    notes.append(i)

# %%
for n in notes:
    msg = mido.Message('note_off', note = n, velocity = 64, time=1440)
    outport.send(msg)

# %% [markdown]
# Now, let's read a file

# %%
mid = MidiFile('/Users/rodolfoocampo/Documents/PhD/DCAI/Audio and midi experiments/Music Transformer/Output - Clair de lune - 6.midi')

# %% [markdown]
# # Managing time
#
# For some reason, the DAW is playing the note whenever the message is sent, ignoring the time attribute in the message. That means we need to manage the time before we send the message.
#
# The time attribute indicates the delta in time between the last message and the current message, given in ticks.
#
# We need to transform these ticks into seconds. To do that, we need to have certain parameters defined:
#
# Ticks per beat and microseconds per beat.
#
# For the above MIDI, those values are
#
# Ticks per beat: 220
# Microseconds per beat: 500,000
#
# Given that we have 1,000,000 microseconds in a second. That means we have two beats per second.
#
# How many seconds are in a tick?
#
# We get that with the following functions

# %%
def seconds_per_tick(ticks_per_beat, microseconds_per_beat):
    return (microseconds_per_beat / 1000000) / ticks_per_beat

def ticks_to_seconds(ticks, ticks_per_beat, microseconds_per_beat):
    return seconds_per_tick(ticks_per_beat, microseconds_per_beat) * ticks

ticks_to_seconds(2000, 220, 500000)
# Out:
# 4.545454545454545

# %% [markdown]
# # Let's send the song! The DAW will magically start playing as if a ghost was controlling it!
#
# We only want to send the MIDI messages that contain information to play notes, not the metamessages. Those events are the note on events, which start with a 144

# %%
for i, track in enumerate(mid.tracks):
    for msg in track:
        if msg.bytes()[0] == 144:
            delta = ticks_to_seconds(msg.time, 220, 500000)
            time.sleep(1)
            outport.send(msg)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-139-9625d414c131> in <module>
#       3         if msg.bytes()[0] == 144:
#       4             delta = ticks_to_seconds(msg.time, 220, 500000)
# ----> 5             time.sleep(1)
#       6             outport.send(msg)
#
# KeyboardInterrupt:

# %% [markdown]
# # Get data from iNaturalist and convert it into a MIDI stream
#
# First just get the data from the API and put it into a dataframe and convert the observed_on date into datetime

# %%
# Set the base url
base_url = 'https://api.inaturalist.org/v1/observations?'

# Set the parameters
params = {'place_id': 50399,
          'per_page': 200,
          'order': 'desc',
          'order_by': 'observed_on'}

# Get the observations
r = requests.get(base_url, params=params)

# Check the status code
if r.status_code == 200:
    print('Success!')
else:
    print('Error')

# The results are returned as a json object. We can convert this to a dataframe using the json_normalize function from the Pandas library.
# Convert the json object to a dataframe
df = pd.json_normalize(r.json()['results'])

df['time_observed_at'] = pd.to_datetime(df['time_observed_at'])
# Out:
# Success!

# %%
df
# Out:
#     quality_grade           time_observed_at taxon_geoprivacy  \
# 0        research  2021-10-13 18:02:00+11:00             open
# 1        needs_id  2021-10-13 07:24:29+11:00             None
# 2        research  2021-10-12 17:50:58+11:00             None
# 3          casual  2021-10-12 17:45:02+11:00             open
# 4        research  2021-10-12 17:45:00+11:00             open
# ..            ...                        ...              ...
# 195      research  2021-10-04 18:17:00+11:00             open
# 196      research  2021-10-04 17:55:00+11:00             open
# 197      needs_id  2021-10-04 06:54:00+00:00             None
# 198      research  2021-10-04 17:39:00+11:00             open
# 199      research  2021-10-04 17:28:00+11:00             open
#
#                                            annotations  \
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3                                                   []
# 4    [{'user_id': 1766254, 'concatenated_attr_val':...
# ..                                                 ...
# 195  [{'user_id': 1766254, 'concatenated_attr_val':...
# 196  [{'user_id': 1766254, 'concatenated_attr_val':...
# 197                                                 []
# 198  [{'user_id': 1766254, 'concatenated_attr_val':...
# 199                                                 []
#
#                                      uuid        id  cached_votes_total  \
# 0    0576ca18-6b84-4f0b-95c7-0b906ec49a52  98086772                   0
# 1    a7150415-f73f-49e1-b9bd-b94eda52fa8e  98087157                   0
# 2    633e4abb-2a76-4ee7-bdbb-8d84390fef74  97991297                   0
# 3    ec444ef3-398a-4360-beff-b90cc7eabc7e  97982200                   0
# 4    6820d722-08b5-4e88-bace-f8aba8f688a8  97987498                   1
# ..                                    ...       ...                 ...
# 195  855167fb-aa86-4cc3-95b1-af7a17c44db2  97127703                   0
# 196  74fbc7ee-e866-4d15-8ef8-4ca14340ac12  97227516                   0
# 197  5778a849-f569-437b-8a33-f9c1c143b6fa  97131532                   0
# 198  f7b44fc4-347f-4ebe-9c85-6df991b5865f  97227515                   0
# 199  1df658cb-ab69-4520-82a3-b7ff8803604c  97124777                   0
#
#      identifications_most_agree             species_guess  \
# 0                          True             Dusky Moorhen
# 1                         False                      None
# 2                          True                       Oat
# 3                         False                      None
# 4                          True     Hydromys chrysogaster
# ..                          ...                       ...
# 195                        True          Peregrine Falcon
# 196                        True           Great Cormorant
# 197                        True                  Venatrix
# 198                        True  Sulphur-crested Cockatoo
# 199                        True        Spotted Grass Frog
#
#      identifications_most_disagree  ...  \
# 0                            False  ...
# 1                            False  ...
# 2                            False  ...
# 3                            False  ...
# 4                            False  ...
# ..                             ...  ...
# 195                          False  ...
# 196                          False  ...
# 197                          False  ...
# 198                          False  ...
# 199                          False  ...
#
#                                          user.icon_url  \
# 0    https://static.inaturalist.org/attachments/use...
# 1    https://static.inaturalist.org/attachments/use...
# 2    https://static.inaturalist.org/attachments/use...
# 3    https://static.inaturalist.org/attachments/use...
# 4    https://static.inaturalist.org/attachments/use...
# ..                                                 ...
# 195  https://static.inaturalist.org/attachments/use...
# 196  https://static.inaturalist.org/attachments/use...
# 197  https://static.inaturalist.org/attachments/use...
# 198  https://static.inaturalist.org/attachments/use...
# 199  https://static.inaturalist.org/attachments/use...
#
#      user.preferences.prefers_project_addition_by  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ..                                            ...
# 195                                           NaN
# 196                                           NaN
# 197                                           NaN
# 198                                           NaN
# 199                                           NaN
#
#      taxon.conservation_status.place_id  taxon.conservation_status.source_id  \
# 0                                   NaN                                  NaN
# 1                                   NaN                                  NaN
# 2                                   NaN                                  NaN
# 3                                   NaN                                  NaN
# 4                                   NaN                                  NaN
# ..                                  ...                                  ...
# 195                                 NaN                                  NaN
# 196                                 NaN                                  NaN
# 197                                 NaN                                  NaN
# 198                                 NaN                                  NaN
# 199                                 NaN                                  NaN
#
#     taxon.conservation_status.user_id taxon.conservation_status.authority  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                 NaN                                 NaN
# 4                                 NaN                                 NaN
# ..                                ...                                 ...
# 195                               NaN                                 NaN
# 196                               NaN                                 NaN
# 197                               NaN                                 NaN
# 198                               NaN                                 NaN
# 199                               NaN                                 NaN
#
#     taxon.conservation_status.status taxon.conservation_status.status_name  \
# 0                                NaN                                   NaN
# 1                                NaN                                   NaN
# 2                                NaN                                   NaN
# 3                                NaN                                   NaN
# 4                                NaN                                   NaN
# ..                               ...                                   ...
# 195                              NaN                                   NaN
# 196                              NaN                                   NaN
# 197                              NaN                                   NaN
# 198                              NaN                                   NaN
# 199                              NaN                                   NaN
#
#      taxon.conservation_status.geoprivacy taxon.conservation_status.iucn
# 0                                     NaN                            NaN
# 1                                     NaN                            NaN
# 2                                     NaN                            NaN
# 3                                     NaN                            NaN
# 4                                     NaN                            NaN
# ..                                    ...                            ...
# 195                                   NaN                            NaN
# 196                                   NaN                            NaN
# 197                                   NaN                            NaN
# 198                                   NaN                            NaN
# 199                                   NaN                            NaN
#
# [200 rows x 144 columns]

# %% [markdown]
# ### Helper function that returns the MIDI notes for the given key, and octaves

# %%
def note_scales(key, typeofkey, octaves):
    start = key
    
    notes = []
    for octave in range(0,octaves):
        if typeofkey == 'major_pentatonic':
            notes.append(start)
            notes.append(start+4)
            notes.append(start+7)
            notes.append(start+8)
        start = start + 12
    return notes

# %%
scale = note_scales(60, 'major_pentatonic', 3)
scale
# Out:
# [60, 64, 67, 68, 72, 76, 79, 80, 84, 88, 91, 92]

# %% [markdown]
# ### Now turn the observations into MIDI messages

# %% [markdown]
# In this case, notes and velocities are randomly selected from a given scale

# %%
# for each observation, calculate the delta in minutes versus the previous observation.
inat_midi = []
for idx, observation in enumerate(df['time_observed_at']):
    if idx != 0:
        delta = (((df['time_observed_at'][idx-1] - df['time_observed_at'][idx]).seconds)/60)*10
        inat_midi.append(mido.Message('note_on', note=random.choice(scale), velocity=random.randint(40, 70), time=min(delta, 700)))

# %% [markdown]
# ## Send the midi messages!

# %%
for msg in inat_midi:
    delta = ticks_to_seconds(msg.time, 220, 500000)
    time.sleep(3)
    outport.send(msg)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-137-f8d945896ac6> in <module>
#       1 for msg in inat_midi:
#       2     delta = ticks_to_seconds(msg.time, 220, 500000)
# ----> 3     time.sleep(3)
#       4     outport.send(msg)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Now let's try a version of this where we take the notes from an AI generated piano song.
#
# Let's take the one we used above, based on Clair de Lune, but we are just going to change the time, so that the time reflects the iNaturalist observations, but the notes are still chosen by the AI

# %% [markdown]
# Just take the note messages from the AI song

# %%
midi_msgs_ai = []
for i, track in enumerate(mid.tracks):
    for msg in track:
        if msg.bytes()[0] == 144:
            midi_msgs_ai.append(msg)

# %%
midi_msgs_ai[0].time = 0
midi_msgs_ai[0]
# Out:
# Message('note_on', channel=0, note=66, velocity=100, time=0)

# %%
inat_midi = []
for idx, observation in enumerate(df['time_observed_at']):
    if idx != 0:
        delta = (((df['time_observed_at'][idx-1] - df['time_observed_at'][idx]).seconds)/60)*100
        midi_msgs_ai[idx].time = min(delta,800)
        inat_midi.append(midi_msgs_ai[idx])

# %%
for msg in inat_midi:
    delta = ticks_to_seconds(msg.time, 220, 500000)
    time.sleep(delta)
    outport.send(msg)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-134-98dce32a1e4e> in <module>
#       1 for msg in inat_midi:
#       2     delta = ticks_to_seconds(msg.time, 220, 500000)
# ----> 3     time.sleep(delta)
#       4     outport.send(msg)
#
# KeyboardInterrupt:

# %%
inat_midi
# Out:
# [Message('note_on', channel=0, note=69, velocity=100, time=800),
#  Message('note_on', channel=0, note=72, velocity=61, time=800),
#  Message('note_on', channel=0, note=75, velocity=65, time=593.3333333333334),
#  Message('note_on', channel=0, note=73, velocity=57, time=3.3333333333333335),
#  Message('note_on', channel=0, note=77, velocity=57, time=90.0),
#  Message('note_on', channel=0, note=69, velocity=0, time=106.66666666666667),
#  Message('note_on', channel=0, note=69, velocity=49, time=75.0),
#  Message('note_on', channel=0, note=72, velocity=0, time=68.33333333333333),
#  Message('note_on', channel=0, note=72, velocity=57, time=191.66666666666669),
#  Message('note_on', channel=0, note=73, velocity=0, time=233.33333333333334),
#  Message('note_on', channel=0, note=75, velocity=0, time=240.0),
#  Message('note_on', channel=0, note=75, velocity=61, time=50.0),
#  Message('note_on', channel=0, note=77, velocity=0, time=113.33333333333333),
#  Message('note_on', channel=0, note=80, velocity=61, time=185.0),
#  Message('note_on', channel=0, note=66, velocity=0, time=65.0),
#  Message('note_on', channel=0, note=69, velocity=0, time=218.33333333333331),
#  Message('note_on', channel=0, note=72, velocity=0, time=800),
#  Message('note_on', channel=0, note=75, velocity=0, time=800),
#  Message('note_on', channel=0, note=80, velocity=0, time=800),
#  Message('note_on', channel=0, note=62, velocity=37, time=800),
#  Message('note_on', channel=0, note=72, velocity=53, time=800),
#  Message('note_on', channel=0, note=82, velocity=57, time=800),
#  Message('note_on', channel=0, note=67, velocity=45, time=200.0),
#  Message('note_on', channel=0, note=67, velocity=0, time=300.0),
#  Message('note_on', channel=0, note=67, velocity=45, time=700.0),
#  Message('note_on', channel=0, note=72, velocity=0, time=0.0),
#  Message('note_on', channel=0, note=72, velocity=41, time=800),
#  Message('note_on', channel=0, note=82, velocity=0, time=800),
#  Message('note_on', channel=0, note=82, velocity=57, time=800),
#  Message('note_on', channel=0, note=62, velocity=0, time=800),
#  Message('note_on', channel=0, note=62, velocity=41, time=800),
#  Message('note_on', channel=0, note=80, velocity=53, time=300.0),
#  Message('note_on', channel=0, note=61, velocity=49, time=800),
#  Message('note_on', channel=0, note=67, velocity=0, time=800),
#  Message('note_on', channel=0, note=67, velocity=53, time=800),
#  Message('note_on', channel=0, note=70, velocity=53, time=85.0),
#  Message('note_on', channel=0, note=72, velocity=0, time=481.66666666666663),
#  Message('note_on', channel=0, note=62, velocity=0, time=800),
#  Message('note_on', channel=0, note=82, velocity=0, time=75.0),
#  Message('note_on', channel=0, note=60, velocity=41, time=800),
#  Message('note_on', channel=0, note=63, velocity=45, time=800),
#  Message('note_on', channel=0, note=68, velocity=49, time=320.0),
#  Message('note_on', channel=0, note=80, velocity=0, time=254.99999999999997),
#  Message('note_on', channel=0, note=70, velocity=0, time=800),
#  Message('note_on', channel=0, note=61, velocity=0, time=800),
#  Message('note_on', channel=0, note=67, velocity=0, time=800),
#  Message('note_on', channel=0, note=70, velocity=53, time=800),
#  Message('note_on', channel=0, note=72, velocity=53, time=800),
#  Message('note_on', channel=0, note=70, velocity=0, time=800),
#  Message('note_on', channel=0, note=70, velocity=49, time=0.0),
#  Message('note_on', channel=0, note=72, velocity=0, time=800),
#  Message('note_on', channel=0, note=68, velocity=0, time=800),
#  Message('note_on', channel=0, note=68, velocity=45, time=800),
#  Message('note_on', channel=0, note=60, velocity=0, time=800),
#  Message('note_on', channel=0, note=63, velocity=0, time=768.3333333333334),
#  Message('note_on', channel=0, note=68, velocity=0, time=146.66666666666666),
#  Message('note_on', channel=0, note=70, velocity=0, time=413.33333333333337),
#  Message('note_on', channel=0, note=60, velocity=49, time=0.0),
#  Message('note_on', channel=0, note=67, velocity=53, time=0.0),
#  Message('note_on', channel=0, note=70, velocity=53, time=300.0),
#  Message('note_on', channel=0, note=60, velocity=0, time=800),
#  Message('note_on', channel=0, note=60, velocity=49, time=176.66666666666666),
#  Message('note_on', channel=0, note=67, velocity=0, time=800),
#  Message('note_on', channel=0, note=67, velocity=49, time=800),
#  Message('note_on', channel=0, note=70, velocity=0, time=800),
#  Message('note_on', channel=0, note=70, velocity=53, time=800),
#  Message('note_on', channel=0, note=73, velocity=57, time=800),
#  Message('note_on', channel=0, note=68, velocity=49, time=200.0),
#  Message('note_on', channel=0, note=60, velocity=0, time=800),
#  Message('note_on', channel=0, note=60, velocity=49, time=800),
#  Message('note_on', channel=0, note=63, velocity=49, time=800),
#  Message('note_on', channel=0, note=67, velocity=0, time=400.0),
#  Message('note_on', channel=0, note=70, velocity=0, time=800),
#  Message('note_on', channel=0, note=73, velocity=0, time=100.0),
#  Message('note_on', channel=0, note=65, velocity=45, time=800),
#  Message('note_on', channel=0, note=68, velocity=0, time=800),
#  Message('note_on', channel=0, note=68, velocity=41, time=800),
#  Message('note_on', channel=0, note=85, velocity=57, time=800),
#  Message('note_on', channel=0, note=77, velocity=49, time=800),
#  Message('note_on', channel=0, note=60, velocity=0, time=476.6666666666667),
#  Message('note_on', channel=0, note=68, velocity=0, time=621.6666666666666),
#  Message('note_on', channel=0, note=61, velocity=33, time=415.00000000000006),
#  Message('note_on', channel=0, note=89, velocity=61, time=168.33333333333334),
#  Message('note_on', channel=0, note=73, velocity=53, time=381.6666666666667),
#  Message('note_on', channel=0, note=77, velocity=0, time=405.0),
#  Message('note_on', channel=0, note=77, velocity=53, time=800),
#  Message('note_on', channel=0, note=63, velocity=0, time=445.0),
#  Message('note_on', channel=0, note=61, velocity=0, time=401.6666666666667),
#  Message('note_on', channel=0, note=85, velocity=0, time=441.6666666666667),
#  Message('note_on', channel=0, note=68, velocity=45, time=790.0),
#  Message('note_on', channel=0, note=73, velocity=0, time=250.0),
#  Message('note_on', channel=0, note=73, velocity=45, time=800),
#  Message('note_on', channel=0, note=65, velocity=0, time=700.0),
#  Message('note_on', channel=0, note=89, velocity=0, time=800),
#  Message('note_on', channel=0, note=80, velocity=49, time=800),
#  Message('note_on', channel=0, note=87, velocity=57, time=800),
#  Message('note_on', channel=0, note=85, velocity=57, time=800),
#  Message('note_on', channel=0, note=87, velocity=0, time=700.0),
#  Message('note_on', channel=0, note=77, velocity=0, time=800),
#  Message('note_on', channel=0, note=73, velocity=0, time=800),
#  Message('note_on', channel=0, note=73, velocity=45, time=800),
#  Message('note_on', channel=0, note=77, velocity=53, time=800),
#  Message('note_on', channel=0, note=62, velocity=37, time=800),
#  Message('note_on', channel=0, note=68, velocity=0, time=33.33333333333333),
#  Message('note_on', channel=0, note=68, velocity=41, time=800),
#  Message('note_on', channel=0, note=85, velocity=0, time=800),
#  Message('note_on', channel=0, note=63, velocity=37, time=800),
#  Message('note_on', channel=0, note=67, velocity=41, time=800),
#  Message('note_on', channel=0, note=70, velocity=41, time=0.0),
#  Message('note_on', channel=0, note=62, velocity=0, time=200.0),
#  Message('note_on', channel=0, note=68, velocity=0, time=100.0),
#  Message('note_on', channel=0, note=73, velocity=0, time=100.0),
#  Message('note_on', channel=0, note=80, velocity=0, time=600.0),
#  Message('note_on', channel=0, note=77, velocity=0, time=0.0),
#  Message('note_on', channel=0, note=72, velocity=45, time=100.0),
#  Message('note_on', channel=0, note=73, velocity=41, time=100.0),
#  Message('note_on', channel=0, note=72, velocity=0, time=500.0),
#  Message('note_on', channel=0, note=72, velocity=37, time=100.0),
#  Message('note_on', channel=0, note=63, velocity=0, time=0.0),
#  Message('note_on', channel=0, note=70, velocity=0, time=800),
#  Message('note_on', channel=0, note=70, velocity=37, time=500.0),
#  Message('note_on', channel=0, note=72, velocity=0, time=100.0),
#  Message('note_on', channel=0, note=67, velocity=0, time=0.0),
#  Message('note_on', channel=0, note=73, velocity=0, time=300.0),
#  Message('note_on', channel=0, note=77, velocity=49, time=400.0),
#  Message('note_on', channel=0, note=63, velocity=33, time=500.0),
#  Message('note_on', channel=0, note=67, velocity=33, time=800),
#  Message('note_on', channel=0, note=70, velocity=0, time=800),
#  Message('note_on', channel=0, note=70, velocity=37, time=100.0),
#  Message('note_on', channel=0, note=73, velocity=49, time=300.0),
#  Message('note_on', channel=0, note=77, velocity=0, time=100.0),
#  Message('note_on', channel=0, note=75, velocity=53, time=800),
#  Message('note_on', channel=0, note=63, velocity=0, time=800),
#  Message('note_on', channel=0, note=70, velocity=0, time=300.0),
#  Message('note_on', channel=0, note=67, velocity=0, time=800),
#  Message('note_on', channel=0, note=56, velocity=37, time=700.0),
#  Message('note_on', channel=0, note=60, velocity=41, time=800),
#  Message('note_on', channel=0, note=63, velocity=49, time=800),
#  Message('note_on', channel=0, note=68, velocity=53, time=80.0),
#  Message('note_on', channel=0, note=73, velocity=0, time=800),
#  Message('note_on', channel=0, note=70, velocity=53, time=271.6666666666667),
#  Message('note_on', channel=0, note=75, velocity=0, time=800),
#  Message('note_on', channel=0, note=72, velocity=53, time=658.3333333333333),
#  Message('note_on', channel=0, note=70, velocity=0, time=800),
#  Message('note_on', channel=0, note=70, velocity=53, time=796.6666666666666),
#  Message('note_on', channel=0, note=56, velocity=0, time=800),
#  Message('note_on', channel=0, note=56, velocity=33, time=800),
#  Message('note_on', channel=0, note=68, velocity=0, time=800.0),
#  Message('note_on', channel=0, note=68, velocity=45, time=400.0),
#  Message('note_on', channel=0, note=56, velocity=0, time=800),
#  Message('note_on', channel=0, note=60, velocity=0, time=800),
#  Message('note_on', channel=0, note=63, velocity=0, time=800),
#  Message('note_on', channel=0, note=68, velocity=0, time=800),
#  Message('note_on', channel=0, note=70, velocity=0, time=200.0),
#  Message('note_on', channel=0, note=72, velocity=0, time=800),
#  Message('note_on', channel=0, note=60, velocity=45, time=466.6666666666667),
#  Message('note_on', channel=0, note=70, velocity=53, time=800),
#  Message('note_on', channel=0, note=53, velocity=41, time=603.3333333333334),
#  Message('note_on', channel=0, note=56, velocity=37, time=653.3333333333334),
#  Message('note_on', channel=0, note=73, velocity=57, time=275.0),
#  Message('note_on', channel=0, note=68, velocity=57, time=800),
#  Message('note_on', channel=0, note=72, velocity=57, time=108.33333333333333),
#  Message('note_on', channel=0, note=60, velocity=0, time=661.6666666666666),
#  Message('note_on', channel=0, note=60, velocity=41, time=0.0),
#  Message('note_on', channel=0, note=70, velocity=0, time=663.3333333333334),
#  Message('note_on', channel=0, note=73, velocity=0, time=103.33333333333334),
#  Message('note_on', channel=0, note=56, velocity=0, time=86.66666666666667),
#  Message('note_on', channel=0, note=60, velocity=0, time=736.6666666666666),
#  Message('note_on', channel=0, note=68, velocity=0, time=78.33333333333333),
#  Message('note_on', channel=0, note=53, velocity=0, time=106.66666666666667),
#  Message('note_on', channel=0, note=72, velocity=0, time=25.0),
#  Message('note_on', channel=0, note=56, velocity=41, time=320.0),
#  Message('note_on', channel=0, note=60, velocity=45, time=380.0),
#  Message('note_on', channel=0, note=67, velocity=49, time=290.0),
#  Message('note_on', channel=0, note=70, velocity=53, time=80.0),
#  Message('note_on', channel=0, note=56, velocity=0, time=170.0),
#  Message('note_on', channel=0, note=56, velocity=45, time=368.3333333333333),
#  Message('note_on', channel=0, note=67, velocity=0, time=491.6666666666667),
#  Message('note_on', channel=0, note=67, velocity=53, time=83.33333333333334),
#  Message('note_on', channel=0, note=70, velocity=0, time=128.33333333333334),
#  Message('note_on', channel=0, note=70, velocity=49, time=426.6666666666667),
#  Message('note_on', channel=0, note=73, velocity=53, time=800),
#  Message('note_on', channel=0, note=55, velocity=49, time=800),
#  Message('note_on', channel=0, note=72, velocity=45, time=800),
#  Message('note_on', channel=0, note=73, velocity=0, time=800),
#  Message('note_on', channel=0, note=67, velocity=0, time=615.0),
#  Message('note_on', channel=0, note=73, velocity=45, time=800),
#  Message('note_on', channel=0, note=70, velocity=0, time=166.66666666666669),
#  Message('note_on', channel=0, note=70, velocity=53, time=800),
#  Message('note_on', channel=0, note=72, velocity=0, time=800),
#  Message('note_on', channel=0, note=56, velocity=0, time=800),
#  Message('note_on', channel=0, note=73, velocity=0, time=800),
#  Message('note_on', channel=0, note=73, velocity=53, time=588.3333333333334),
#  Message('note_on', channel=0, note=70, velocity=0, time=611.6666666666666),
#  Message('note_on', channel=0, note=70, velocity=33, time=800),
#  Message('note_on', channel=0, note=72, velocity=53, time=800),
#  Message('note_on', channel=0, note=70, velocity=0, time=100.0),
#  Message('note_on', channel=0, note=73, velocity=0, time=800),
#  Message('note_on', channel=0, note=60, velocity=0, time=800)]
